# %% [markdown]
# <a href="https://colab.research.google.com/github/MuftiqurBista1111/Unisnacks_Data_Forecasting/blob/main/Post_Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/LSTM_Cus_quantity (2).csv", parse_dates=True)

# %%
df
# Out:
#                                             Unnamed: 0  Unnamed: 1  \
# 0    ALX001 648 Group Ltd/Nagoya Oriental Store Hat...        1028
# 1                                                  NaN         918
# 2                                                  NaN         920
# 3                                                  NaN         922
# 4                                                  NaN         923
# ..                                                 ...         ...
# 143                                                NaN         925
# 144                                                NaN         952
# 145                                                NaN         954
# 146                                                NaN         489
# 147                                                NaN        1023
#
#      Product Name                          Forecasted Value_ARIMA
# 0            1028  2024-06-30    1.0\nFreq: Q-DEC, dtype: float64
# ...

# %%
# Rename 'Unnamed: 0' column to 'Customer Name'
df.rename(columns={'Unnamed: 0': 'Customer Name'}, inplace=True)

# Drop 'Unnamed: 1' column
df.drop(columns=['Unnamed: 1'], inplace=True)

# Save the modified DataFrame back to a CSV file if needed
# df.to_csv('modified_file.csv', index=False)

# Display the first few rows of the modified DataFrame
print(df.head())
# Out:
#                                        Customer Name  Product Name  \
# 0  ALX001 648 Group Ltd/Nagoya Oriental Store Hat...          1028
# 1                                                NaN           918
# 2                                                NaN           920
# 3                                                NaN           922
# 4                                                NaN           923
#
#                            Forecasted Value_ARIMA
# 0  2024-06-30    1.0\nFreq: Q-DEC, dtype: float64
# 1  2024-06-30    0.0\nFreq: Q-DEC, dtype: float64
# 2  2024-06-30    1.0\nFreq: Q-DEC, dtype: float64
# 3  2024-06-30    1.0\nFreq: Q-DEC, dtype: float64
# 4  2024-06-30    1.0\nFreq: Q-DEC, dtype: float64

# %%
df
# Out:
#                                          Customer Name  Product Name  \
# 0    ALX001 648 Group Ltd/Nagoya Oriental Store Hat...          1028
# 1                                                  NaN           918
# 2                                                  NaN           920
# 3                                                  NaN           922
# 4                                                  NaN           923
# ..                                                 ...           ...
# 143                                                NaN           925
# 144                                                NaN           952
# 145                                                NaN           954
# 146                                                NaN           489
# 147                                                NaN          1023
#
#                              Forecasted Value_ARIMA
# 0    2024-06-30    1.0\nFreq: Q-DEC, dtype: float64
# ...

# %%
# Display data type of 'Forecasted Value_ARIMA' column
print("Data Type of Forecasted Value_ARIMA Column:")
print(df['Forecasted Value_ARIMA'].dtype)

# Display one row of data from 'Forecasted Value_ARIMA' column
print("\nOne Row of Data from Forecasted Value_ARIMA Column:")
print(df['Forecasted Value_ARIMA'].head(1))
# Out:
# Data Type of Forecasted Value_ARIMA Column:
# object
#
# One Row of Data from Forecasted Value_ARIMA Column:
# 0    2024-06-30    1.0\nFreq: Q-DEC, dtype: float64
# Name: Forecasted Value_ARIMA, dtype: object

# %%
# Convert 'Forecasted Value_ARIMA' column to string type
df['Forecasted Value_ARIMA'] = df['Forecasted Value_ARIMA'].astype(str)

# Filter the DataFrame to keep rows where 'Forecasted Value_ARIMA' column contains '1.0'
df_filtered = df[df['Forecasted Value_ARIMA'].str.contains('1.0')]

# Display the filtered DataFrame
print("Filtered DataFrame:")
print(df_filtered)

# Save the filtered DataFrame back to a CSV file if needed
# df_filtered.to_csv('filtered_file.csv', index=False)
# Out:
# Filtered DataFrame:
#                                          Customer Name  Product Name  \
# 0    ALX001 648 Group Ltd/Nagoya Oriental Store Hat...          1028
# 2                                                  NaN           920
# 3                                                  NaN           922
# 4                                                  NaN           923
# 5                                                  NaN           925
# ..                                                 ...           ...
# 139                                                NaN           931
# 140                                                NaN           935
# 141                                                NaN           918
# 144                                                NaN           952
# 145                                                NaN           954
#
#                              Forecasted Value_ARIMA
# 0    2024-06-30    1.0\nFreq: Q-DEC, dtype: float64
# ...

# %%
df_filtered
# Out:
#                                          Customer Name  Product Name  \
# 0    ALX001 648 Group Ltd/Nagoya Oriental Store Hat...          1028
# 2                                                  NaN           920
# 3                                                  NaN           922
# 4                                                  NaN           923
# 5                                                  NaN           925
# ..                                                 ...           ...
# 139                                                NaN           931
# 140                                                NaN           935
# 141                                                NaN           918
# 144                                                NaN           952
# 145                                                NaN           954
#
#                              Forecasted Value_ARIMA
# 0    2024-06-30    1.0\nFreq: Q-DEC, dtype: float64
# ...
